# %% [markdown]
# Big Data And Society: Lab 3
# =====

# %% [markdown]
# # APIs and Data Scraping: Getting Twitter Data

# %% [markdown]
# ### 0. Set up a Twitter Application
#
# This week we are going to scrape data from the Twitter API and make some plots! We are going to use the Twitter REST API, which lets us query and retreive samples of Tweets. To do this, you need API keys that are associated with your account. Your API keys are secret and unique to you and only you, and they gives you access to Twitter data through the API.
#
# There are a couple of ways to get Twitter data, the REST API is just one of them. The others are to set up a Streamer (which streams real time tweets), or to access the Firehose (this means everything!). Read [this article](https://brightplanet.com/2013/06/twitter-firehose-vs-twitter-api-whats-the-difference-and-why-should-you-care/) for a nice comparison between the methods.
#
# The Twitter REST API is best place to start and what we will use in class. Follow the following steps to get your keys.
#
# * Create a twitter account if you do not already have one.
# * Go to [https://apps.twitter.com/](https://apps.twitter.com/) and log in with your twitter credentials.
# * Click **"Create New App"** in the upper right corner
# * Fill out the form, give it a name like **data_getter_yourname** and a description, agree to the terms, and click **"Create your Twitter application"** *Note: The form will ask for a website. You can put the github.io page you made as the URL. **It is OK for your callback URL to be blank.***
# * In the next page, click on **Keys and Access Tokens** tab, and copy your "Consumer Key (API Key)" and "Consumer Key (API Secret)".
#
# We need a Python file that will contain the **Twitter** keys. It is never a good idea to host these keys on a public website like **github**, so one way to keep them private is importing the keys as a variable from a separate, untracked file. Open your text editor, and in the materials for the week, *PASTE* these keys into the **twitter-keys.py** file and save the file. Using this method, we can then import the keys and use them on a repeated basis, and we can choose not to put this file on Github. **Make sure they are saved as strings!**
#
# **!!IMPORTANT NOTE!! NEVER SAVE YOUR TWITTER_KEY.PY FILE TO GITHUB. IF YOU DO, PEOPLE CAN SEE YOUR KEYS AND USE THEM. KEEP THESE ON YOUR MACHINE.**

# %% [markdown]
# ### 1. Importing the Libraries and Twitter Keys
#
# We will be using **Twython**, a Python library that provides wrappers around Twitter's API. To install **Twython** on a terminal or the command line, run the following command:
#
# ```
# pip install twython
# ```
#
# We also need to import the keys we just got from Twitter to be accessible to our code. View the contents of **twitter_key.py** to see your keys. These should both be strings.
#
# ```
# # In the file you should define two variables:
# api_key = "your twitter key"
# api_secret = "your twitter secret"
# ```
#
# Import the libraries:

# %%
# Import libraries
import json
import time
import threading
from datetime import datetime
from twython import Twython

# Imports the keys from the python file
from twitter_key import api_key, api_secret

# %% [markdown]
# ### 2. Set Up Twython, Get an OAuth2 Token, and Create your Twython Object
#
# In this next step, assign the keys to variables and set up our instance of Twython to work with your account.
#
# Doing this requires our authentication with Twitter using our keys. Twitter uses something called [OAuth](https://dev.twitter.com/oauth) for API authentication. There are two types of OAuth authentication. OAuth1 provides user authentication to the API, and is required to post tweets and issue requests on behalf of users. OAuth 2 is [application-only authentication](https://dev.twitter.com/oauth/application-only), and has higher rate limits but doesn't allow you to post on users behalf. Because we can get more tweets using it, we are going to use OAuth2.
#
# **OAuth 2 requires a Third Access token you must request using the API. This next step will set everything up for us.**
#
# In the last part of this, we create a **Twython** object and call it **my_twython**; this object simplifies the access to the [Twitter API](https://dev.twitter.com/overview/documentation), and provides methods for accessing the API’s endpoints. The first function fetches tweets with a given query at a given lat-long. We will be using the search parameters to hit the APIs endpoint. We need to provide the lat/lon of the centroid of the area we want to query, maximum number of tweets to return, and area within the centroid to search for, among others.

# %%
# Assigns the keys to the variables
APP_KEY = api_key
APP_SECRET = api_secret

# Create a Twython object called Twitter
# Set this up using your Twitter Keys
# Say we are going to use OAuth 2
twython_setup = Twython(APP_KEY, APP_SECRET, oauth_version=2)

# Get an OAuth2 access token, save as variable so we can launch our 
OAUTH2_ACCESS_TOKEN = twython_setup.obtain_access_token()

# Create a Twython Object we will use for our access to the API
my_twython = Twython(APP_KEY, access_token=OAUTH2_ACCESS_TOKEN)

# %% [markdown]
# For reference, the Twython documentation and all available commands can be found here. [https://twython.readthedocs.io/en/latest/usage/starting_out.html](https://twython.readthedocs.io/en/latest/usage/starting_out.html)

# %% [markdown]
# ### 3. Query the Twitter API to get Tweets at a Location
#
# Next, let's do a search and get some tweets! Specifically, set up a function that will use the **search** API. Read more about the **search** API [here](https://dev.twitter.com/rest/reference/get/search/tweets).
#
# The **Search API** can take many parameters for querying tweets. Twitter has a nice page of what you can use as query parameters here [https://dev.twitter.com/rest/public/search](https://dev.twitter.com/rest/public/search).
#
# The Twitter API has rate limits that limit how quickly you can download data. This is to try to lighten the load on their servers. We are using the Search API with **OAuth2 (Application) Access** - which limits us to **450 in 15 minutes** Read about the [Rate Limits](https://dev.twitter.com/rest/public/rate-limiting) here. This means, in our following steps, always follow the guideline that you will not be able to get more than 450 tweets in 15 minutes, or Twitter might lock your access.

# %%
# Input the search term you want to search on
search_term='' # SET A SEARCH TERM LIKE 'TRUMP'
# CAN LEAVE search_term BLANK IF YOU WANT ALL TWEETS NEAR A SPECIFIC LOCATION
# Setup a Lat Lon
latlong=[40.261455,-76.882553] # Downtown Harrisburg, PA - Capital of Pennsylvania
# Setup a search distance
distance='25mi'
# Set result type (can be 'recent', 'popular', or 'mixed')
type_of_result='recent'
# Set number of results (up to 100, remember you can only get 450 in 15 minutes)
number_of_tweets=15


# Fetches tweets with a given query at a given lat-long.
def get_tweets_by_location( latlong=None ):
    # Uses the search function to hit the APIs endpoints and look for recent tweets within the area
    results = my_twython.search(q=search_term, geocode=str(latlong[0])+','+str(latlong[1])+','+ distance, result_type=type_of_result, count=number_of_tweets)
    # Returns the only the statuses from the resulting JSON
    return results['statuses']

# test run our function
get_tweets_by_location(latlong)
# Out:
# [{'contributors': None,
#   'coordinates': None,
#   'created_at': 'Mon Mar 06 15:24:09 +0000 2017',
#   'entities': {'hashtags': [{'indices': [117, 121], 'text': 'FTK'}],
#    'symbols': [],
#    'urls': [],
#    'user_mentions': [{'id': 2458040166,
#      'id_str': '2458040166',
#      'indices': [3, 16],
#      'name': 'Four Diamonds',
#      'screen_name': 'fourdiamonds'},
#     {'id': 48176222,
#      'id_str': '48176222',
#      'indices': [34, 46],
#      'name': 'Kevin Duckworth',
#      'screen_name': 'kcduckworth'},
#     {'id': 2908494444,
#      'id_str': '2908494444',
#      'indices': [48, 62],
#      'name': 'Dallastown Mini-THON',
#      'screen_name': 'dtownminithon'},
#     {'id': 2340796542,
#      'id_str': '2340796542',
#      'indices': [63, 79],
#      'name': 'Dallastown Area HS',
#      'screen_name': 'DtownHighSchool'}]},
#   'favorite_count': 0,
#   'favorited': False,
#   'geo': None,
#   'id': 838772194868088832,
#   'id_str': '838772194868088832',
#   'in_reply_to_screen_name': None,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'is_quote_status': False,
#   'lang': 'en',
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'place': None,
#   'retweet_count': 3,
#   'retweeted': False,
#   'retweeted_status': {'contributors': None,
#    'coordinates': None,
#    'created_at': 'Mon Mar 06 14:05:09 +0000 2017',
#    'entities': {'hashtags': [{'indices': [99, 103], 'text': 'FTK'}],
#     'media': [{'display_url': 'pic.twitter.com/DsePBptML5',
#       'expanded_url': 'https://twitter.com/fourdiamonds/status/838752311753199616/photo/1',
#       'id': 838752308284403712,
#       'id_str': '838752308284403712',
#       'indices': [105, 128],
#       'media_url': 'http://pbs.twimg.com/media/C6PYx83UsAAX3I-.jpg',
#       'media_url_https': 'https://pbs.twimg.com/media/C6PYx83UsAAX3I-.jpg',
#       'sizes': {'large': {'h': 613, 'resize': 'fit', 'w': 935},
#        'medium': {'h': 613, 'resize': 'fit', 'w': 935},
#        'small': {'h': 446, 'resize': 'fit', 'w': 680},
#        'thumb': {'h': 150, 'resize': 'crop', 'w': 150}},
#       'type': 'photo',
#       'url': 'https://t.co/DsePBptML5'}],
#     'symbols': [],
#     'urls': [],
#     'user_mentions': [{'id': 48176222,
#       'id_str': '48176222',
#       'indices': [16, 28],
#       'name': 'Kevin Duckworth',
#       'screen_name': 'kcduckworth'},
#      {'id': 2908494444,
#       'id_str': '2908494444',
#       'indices': [30, 44],
#       'name': 'Dallastown Mini-THON',
#       'screen_name': 'dtownminithon'},
#      {'id': 2340796542,
#       'id_str': '2340796542',
#       'indices': [45, 61],
#       'name': 'Dallastown Area HS',
#       'screen_name': 'DtownHighSchool'}]},
#    'extended_entities': {'media': [{'display_url': 'pic.twitter.com/DsePBptML5',
#       'expanded_url': 'https://twitter.com/fourdiamonds/status/838752311753199616/photo/1',
#       'id': 838752308284403712,
#       'id_str': '838752308284403712',
#       'indices': [105, 128],
#       'media_url': 'http://pbs.twimg.com/media/C6PYx83UsAAX3I-.jpg',
#       'media_url_https': 'https://pbs.twimg.com/media/C6PYx83UsAAX3I-.jpg',
#       'sizes': {'large': {'h': 613, 'resize': 'fit', 'w': 935},
#        'medium': {'h': 613, 'resize': 'fit', 'w': 935},
#        'small': {'h': 446, 'resize': 'fit', 'w': 680},
#        'thumb': {'h': 150, 'resize': 'crop', 'w': 150}},
#       'type': 'photo',
#       'url': 'https://t.co/DsePBptML5'}]},
#    'favorite_count': 6,
#    'favorited': False,
#    'geo': None,
#    'id': 838752311753199616,
#    'id_str': '838752311753199616',
#    'in_reply_to_screen_name': None,
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'is_quote_status': False,
#    'lang': 'en',
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'place': None,
#    'possibly_sensitive': False,
#    'retweet_count': 3,
#    'retweeted': False,
#    'source': '<a href="http://www.hootsuite.com" rel="nofollow">Hootsuite</a>',
#    'text': 'Amazing job! MT @kcduckworth: @dtownminithon @DtownHighSchool,  congratulations on raising $60,219 #FTK! https://t.co/DsePBptML5',
#    'truncated': False,
#    'user': {'contributors_enabled': False,
#     'created_at': 'Tue Apr 22 12:10:31 +0000 2014',
#     'default_profile': False,
#     'default_profile_image': False,
#     'description': 'The Four Diamonds mission is to conquer childhood cancer by supporting world-class care and life-saving research to benefit kids everywhere. #FTK',
#     'entities': {'description': {'urls': []},
#      'url': {'urls': [{'display_url': 'fourdiamonds.org',
#         'expanded_url': 'http://www.fourdiamonds.org',
#         'indices': [0, 23],
#         'url': 'https://t.co/WsO1oL7nzk'}]}},
#     'favourites_count': 2758,
#     'follow_request_sent': None,
#     'followers_count': 6192,
#     'following': None,
#     'friends_count': 1019,
#     'geo_enabled': True,
#     'has_extended_profile': False,
#     'id': 2458040166,
#     'id_str': '2458040166',
#     'is_translation_enabled': False,
#     'is_translator': False,
#     'lang': 'en',
#     'listed_count': 25,
#     'location': 'Hershey, PA',
#     'name': 'Four Diamonds',
#     'notifications': None,
#     'profile_background_color': '003896',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme15/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme15/bg.png',
#     'profile_background_tile': False,
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/2458040166/1487546493',
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/771079991387787264/ftzx3RQM_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/771079991387787264/ftzx3RQM_normal.jpg',
#     'profile_link_color': '003896',
#     'profile_sidebar_border_color': '000000',
#     'profile_sidebar_fill_color': '000000',
#     'profile_text_color': '000000',
#     'profile_use_background_image': False,
#     'protected': False,
#     'screen_name': 'fourdiamonds',
#     'statuses_count': 8553,
#     'time_zone': 'Eastern Time (US & Canada)',
#     'translator_type': 'none',
#     'url': 'https://t.co/WsO1oL7nzk',
#     'utc_offset': -18000,
#     'verified': False}},
#   'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#   'text': 'RT @fourdiamonds: Amazing job! MT @kcduckworth: @dtownminithon @DtownHighSchool,  congratulations on raising $60,219 #FTK! https://t.co/Dse…',
#   'truncated': False,
#   'user': {'contributors_enabled': False,
#    'created_at': 'Thu Jan 02 00:39:43 +0000 2014',
#    'default_profile': True,
#    'default_profile_image': False,
#    'description': 'full of life and full of love',
#    'entities': {'description': {'urls': []},
#     'url': {'urls': [{'display_url': 'THON.org',
#        'expanded_url': 'http://www.THON.org',
#        'indices': [0, 23],
#        'url': 'https://t.co/yONjf6AWWY'}]}},
#    'favourites_count': 2622,
#    'follow_request_sent': None,
#    'followers_count': 168,
#    'following': None,
#    'friends_count': 248,
#    'geo_enabled': True,
#    'has_extended_profile': True,
#    'id': 2272269074,
#    'id_str': '2272269074',
#    'is_translation_enabled': False,
#    'is_translator': False,
#    'lang': 'en',
#    'listed_count': 1,
#    'location': '',
#    'name': 'hanna',
#    'notifications': None,
#    'profile_background_color': 'C0DEED',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/2272269074/1488031731',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/835491746872188929/lzuzAVgN_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/835491746872188929/lzuzAVgN_normal.jpg',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'protected': False,
#    'screen_name': 'EarthToHanna_',
#    'statuses_count': 2627,
#    'time_zone': 'Eastern Time (US & Canada)',
#    'translator_type': 'none',
#    'url': 'https://t.co/yONjf6AWWY',
#    'utc_offset': -18000,
#    'verified': False}},
#  {'contributors': None,
#   'coordinates': None,
#   'created_at': 'Mon Mar 06 15:24:08 +0000 2017',
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'urls': [],
#    'user_mentions': [{'id': 40145940,
#      'id_str': '40145940',
#      'indices': [3, 17],
#      'name': 'Rick Smith',
#      'screen_name': 'RickSmithShow'}]},
#   'favorite_count': 0,
#   'favorited': False,
#   'geo': None,
#   'id': 838772188434030597,
#   'id_str': '838772188434030597',
#   'in_reply_to_screen_name': None,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'is_quote_status': False,
#   'lang': 'en',
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'place': None,
#   'retweet_count': 12,
#   'retweeted': False,
#   'retweeted_status': {'contributors': None,
#    'coordinates': None,
#    'created_at': 'Mon Mar 06 15:10:35 +0000 2017',
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'urls': [],
#     'user_mentions': []},
#    'favorite_count': 35,
#    'favorited': False,
#    'geo': None,
#    'id': 838768780704681984,
#    'id_str': '838768780704681984',
#    'in_reply_to_screen_name': None,
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'is_quote_status': False,
#    'lang': 'en',
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'place': None,
#    'retweet_count': 12,
#    'retweeted': False,
#    'source': '<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>',
#    'text': 'Remember, it was only Tuesday we were saying Trump almost looked presidential &amp; we were exclaiming over his ability to read fm teleprompter',
#    'truncated': False,
#    'user': {'contributors_enabled': False,
#     'created_at': 'Fri May 15 01:48:17 +0000 2009',
#     'default_profile': False,
#     'default_profile_image': False,
#     'description': 'Patriotic American Bringing #TheResistance to your Radio daily 10am-Noon\n\nYour TV Sat. 7pm @freespeechtv\npodcast@ https://t.co/8dI7z9CmM9',
#     'entities': {'description': {'urls': [{'display_url': 'thericksmithshow.com',
#         'expanded_url': 'http://thericksmithshow.com',
#         'indices': [114, 137],
#         'url': 'https://t.co/8dI7z9CmM9'}]},
#      'url': {'urls': [{'display_url': 'thericksmithshow.com',
#         'expanded_url': 'http://thericksmithshow.com',
#         'indices': [0, 23],
#         'url': 'https://t.co/8dI7z9CmM9'}]}},
#     'favourites_count': 1983,
#     'follow_request_sent': None,
#     'followers_count': 15175,
#     'following': None,
#     'friends_count': 3198,
#     'geo_enabled': True,
#     'has_extended_profile': True,
#     'id': 40145940,
#     'id_str': '40145940',
#     'is_translation_enabled': False,
#     'is_translator': False,
#     'lang': 'en',
#     'listed_count': 326,
#     'location': 'Harrisburg, PA',
#     'name': 'Rick Smith',
#     'notifications': None,
#     'profile_background_color': '000000',
#     'profile_background_image_url': 'http://pbs.twimg.com/profile_background_images/192282195/twitter.png',
#     'profile_background_image_url_https': 'https://pbs.twimg.com/profile_background_images/192282195/twitter.png',
#     'profile_background_tile': False,
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/40145940/1452708901',
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/834548465342496768/uSweCRrE_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/834548465342496768/uSweCRrE_normal.jpg',
#     'profile_link_color': '0084B4',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': '000000',
#     'profile_text_color': 'E37171',
#     'profile_use_background_image': True,
#     'protected': False,
#     'screen_name': 'RickSmithShow',
#     'statuses_count': 29304,
#     'time_zone': 'Eastern Time (US & Canada)',
#     'translator_type': 'none',
#     'url': 'https://t.co/8dI7z9CmM9',
#     'utc_offset': -18000,
#     'verified': False}},
#   'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#   'text': 'RT @RickSmithShow: Remember, it was only Tuesday we were saying Trump almost looked presidential &amp; we were exclaiming over his ability to r…',
#   'truncated': False,
#   'user': {'contributors_enabled': False,
#    'created_at': 'Wed Jan 07 17:52:30 +0000 2015',
#    'default_profile': True,
#    'default_profile_image': False,
#    'description': "I'm a 53 yr old Jewish woman who is surprise, surprise a liberal! With a gay kid and a black boyfriend!",
#    'entities': {'description': {'urls': []}},
#    'favourites_count': 41451,
#    'follow_request_sent': None,
#    'followers_count': 414,
#    'following': None,
#    'friends_count': 144,
#    'geo_enabled': False,
#    'has_extended_profile': True,
#    'id': 2963623381,
#    'id_str': '2963623381',
#    'is_translation_enabled': False,
#    'is_translator': False,
#    'lang': 'en',
#    'listed_count': 7,
#    'location': 'Houston, TX',
#    'name': 'Linda Kathryn Bresla',
#    'notifications': None,
#    'profile_background_color': 'C0DEED',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/2963623381/1484076283',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/827618840955740160/SAlTJJxi_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/827618840955740160/SAlTJJxi_normal.jpg',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'protected': False,
#    'screen_name': 'bresla_linda',
#    'statuses_count': 24140,
#    'time_zone': None,
#    'translator_type': 'none',
#    'url': None,
#    'utc_offset': None,
#    'verified': False}},
#  {'contributors': None,
#   'coordinates': None,
#   'created_at': 'Mon Mar 06 15:24:06 +0000 2017',
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'urls': [{'display_url': 'fb.me/8cEocgHBk',
#      'expanded_url': 'http://fb.me/8cEocgHBk',
#      'indices': [116, 139],
#      'url': 'https://t.co/ymQUJwyd2n'}],
#    'user_mentions': []},
#   'favorite_count': 0,
#   'favorited': False,
#   'geo': None,
#   'id': 838772182587146241,
#   'id_str': '838772182587146241',
#   'in_reply_to_screen_name': None,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'is_quote_status': False,
#   'lang': 'en',
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'place': None,
#   'possibly_sensitive': False,
#   'retweet_count': 0,
#   'retweeted': False,
#   'source': '<a href="http://www.facebook.com/twitter" rel="nofollow">Facebook</a>',
#   'text': 'Earn your credit this weekend! A huge thanks to those of you who have signed up already, but we still need about... https://t.co/ymQUJwyd2n',
#   'truncated': False,
#   'user': {'contributors_enabled': False,
#    'created_at': 'Fri Apr 10 15:48:50 +0000 2015',
#    'default_profile': False,
#    'default_profile_image': False,
#    'description': 'DASC : Dillsburg Area Soccer Club',
#    'entities': {'description': {'urls': []},
#     'url': {'urls': [{'display_url': 'dascsoccer.org',
#        'expanded_url': 'http://www.dascsoccer.org',
#        'indices': [0, 22],
#        'url': 'http://t.co/SuauwFpHkP'}]}},
#    'favourites_count': 8,
#    'follow_request_sent': None,
#    'followers_count': 40,
#    'following': None,
#    'friends_count': 45,
#    'geo_enabled': False,
#    'has_extended_profile': False,
#    'id': 3153979462,
#    'id_str': '3153979462',
#    'is_translation_enabled': False,
#    'is_translator': False,
#    'lang': 'en',
#    'listed_count': 0,
#    'location': 'Dillsburg PA',
#    'name': 'Dillsburg Soccer',
#    'notifications': None,
#    'profile_background_color': '000000',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/3153979462/1458239914',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/586558715190321152/vAEIV4Y8_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/586558715190321152/vAEIV4Y8_normal.jpg',
#    'profile_link_color': '3B94D9',
#    'profile_sidebar_border_color': '000000',
#    'profile_sidebar_fill_color': '000000',
#    'profile_text_color': '000000',
#    'profile_use_background_image': False,
#    'protected': False,
#    'screen_name': 'DillsburgSoccer',
#    'statuses_count': 391,
#    'time_zone': None,
#    'translator_type': 'none',
#    'url': 'http://t.co/SuauwFpHkP',
#    'utc_offset': None,
#    'verified': False}},
#  {'contributors': None,
#   'coordinates': None,
#   'created_at': 'Mon Mar 06 15:24:03 +0000 2017',
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'urls': [{'display_url': 'wp.me/p5hgQ6-22i3',
#      'expanded_url': 'http://wp.me/p5hgQ6-22i3',
#      'indices': [71, 94],
#      'url': 'https://t.co/3Ly4Nphjui'}],
#    'user_mentions': [{'id': 15145034,
#      'id_str': '15145034',
#      'indices': [3, 13],
#      'name': 'abc27 WHTM',
#      'screen_name': 'abc27News'}]},
#   'favorite_count': 0,
#   'favorited': False,
#   'geo': None,
#   'id': 838772167479283713,
#   'id_str': '838772167479283713',
#   'in_reply_to_screen_name': None,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'is_quote_status': False,
#   'lang': 'en',
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'place': None,
#   'possibly_sensitive': False,
#   'retweet_count': 1,
#   'retweeted': False,
#   'retweeted_status': {'contributors': None,
#    'coordinates': None,
#    'created_at': 'Mon Mar 06 14:53:09 +0000 2017',
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'urls': [{'display_url': 'wp.me/p5hgQ6-22i3',
#       'expanded_url': 'http://wp.me/p5hgQ6-22i3',
#       'indices': [56, 79],
#       'url': 'https://t.co/3Ly4Nphjui'}],
#     'user_mentions': []},
#    'favorite_count': 1,
#    'favorited': False,
#    'geo': None,
#    'id': 838764393089417217,
#    'id_str': '838764393089417217',
#    'in_reply_to_screen_name': None,
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'is_quote_status': False,
#    'lang': 'en',
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'place': None,
#    'possibly_sensitive': False,
#    'retweet_count': 1,
#    'retweeted': False,
#    'source': '<a href="http://publicize.wp.com/" rel="nofollow">WordPress.com</a>',
#    'text': 'Keystone pipeline won’t have to be built using US steel https://t.co/3Ly4Nphjui',
#    'truncated': False,
#    'user': {'contributors_enabled': False,
#     'created_at': 'Tue Jun 17 12:36:05 +0000 2008',
#     'default_profile': False,
#     'default_profile_image': False,
#     'description': "Central Pennsylvania's leader in local news, sports and information. Social media policy: https://t.co/XJQMn2Ij0R",
#     'entities': {'description': {'urls': [{'display_url': 'abc27.com/social-media-p…',
#         'expanded_url': 'http://abc27.com/social-media-policy/',
#         'indices': [90, 113],
#         'url': 'https://t.co/XJQMn2Ij0R'}]},
#      'url': {'urls': [{'display_url': 'abc27.com',
#         'expanded_url': 'http://www.abc27.com',
#         'indices': [0, 23],
#         'url': 'https://t.co/INzj9IQB4I'}]}},
#     'favourites_count': 948,
#     'follow_request_sent': None,
#     'followers_count': 83714,
#     'following': None,
#     'friends_count': 852,
#     'geo_enabled': True,
#     'has_extended_profile': False,
#     'id': 15145034,
#     'id_str': '15145034',
#     'is_translation_enabled': False,
#     'is_translator': False,
#     'lang': 'en',
#     'listed_count': 724,
#     'location': 'Harrisburg, PA',
#     'name': 'abc27 WHTM',
#     'notifications': None,
#     'profile_background_color': '050505',
#     'profile_background_image_url': 'http://pbs.twimg.com/profile_background_images/880914624/445a265e97670072b6d5500a5c7f15d0.jpeg',
#     'profile_background_image_url_https': 'https://pbs.twimg.com/profile_background_images/880914624/445a265e97670072b6d5500a5c7f15d0.jpeg',
#     'profile_background_tile': False,
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/15145034/1486059038',
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/802173436655181825/ef98EOnl_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/802173436655181825/ef98EOnl_normal.jpg',
#     'profile_link_color': '0084B4',
#     'profile_sidebar_border_color': 'FFFFFF',
#     'profile_sidebar_fill_color': 'DDFFCC',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'protected': False,
#     'screen_name': 'abc27News',
#     'statuses_count': 120622,
#     'time_zone': 'Eastern Time (US & Canada)',
#     'translator_type': 'none',
#     'url': 'https://t.co/INzj9IQB4I',
#     'utc_offset': -18000,
#     'verified': True}},
#   'source': '<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>',
#   'text': 'RT @abc27News: Keystone pipeline won’t have to be built using US steel https://t.co/3Ly4Nphjui',
#   'truncated': False,
#   'user': {'contributors_enabled': False,
#    'created_at': 'Tue May 08 01:13:19 +0000 2007',
#    'default_profile': False,
#    'default_profile_image': False,
#    'description': 'Be kinder than necessary, for everyone you meet is fighting some kind of battle. --Unknown',
#    'entities': {'description': {'urls': []},
#     'url': {'urls': [{'display_url': 'ricjr.org',
#        'expanded_url': 'http://www.ricjr.org',
#        'indices': [0, 22],
#        'url': 'http://t.co/3TujxTfk37'}]}},
#    'favourites_count': 112,
#    'follow_request_sent': None,
#    'followers_count': 1332,
#    'following': None,
#    'friends_count': 611,
#    'geo_enabled': True,
#    'has_extended_profile': False,
#    'id': 5849252,
#    'id_str': '5849252',
#    'is_translation_enabled': False,
#    'is_translator': False,
#    'lang': 'en',
#    'listed_count': 428,
#    'location': 'Ocean City, Maryland',
#    'name': 'Roy Crockett',
#    'notifications': None,
#    'profile_background_color': 'DADDC0',
#    'profile_background_image_url': 'http://pbs.twimg.com/profile_background_images/543857634/xdb6f49d5a584c72d699ecc5a9002b5c.jpg',
#    'profile_background_image_url_https': 'https://pbs.twimg.com/profile_background_images/543857634/xdb6f49d5a584c72d699ecc5a9002b5c.jpg',
#    'profile_background_tile': False,
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/5849252/1398260348',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/797575448838414336/r9vcaydH_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/797575448838414336/r9vcaydH_normal.jpg',
#    'profile_link_color': '877F63',
#    'profile_sidebar_border_color': 'E2EAEF',
#    'profile_sidebar_fill_color': 'E2EAEF',
#    'profile_text_color': '6C961C',
#    'profile_use_background_image': True,
#    'protected': False,
#    'screen_name': 'rcrockett',
#    'statuses_count': 364080,
#    'time_zone': 'Eastern Time (US & Canada)',
#    'translator_type': 'regular',
#    'url': 'http://t.co/3TujxTfk37',
#    'utc_offset': -18000,
#    'verified': False}},
#  {'contributors': None,
#   'coordinates': None,
#   'created_at': 'Mon Mar 06 15:23:59 +0000 2017',
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'urls': [],
#    'user_mentions': [{'id': 545640747,
#      'id_str': '545640747',
#      'indices': [0, 10],
#      'name': 'Lyra',
#      'screen_name': 'AshCoyote'},
#     {'id': 168717945,
#      'id_str': '168717945',
#      'indices': [11, 20],
#      'name': 'Maned Vega 🦊',
#      'screen_name': 'chipfoxx'},
#     {'id': 155805312,
#      'id_str': '155805312',
#      'indices': [75, 86],
#      'name': 'Made Fur You, INC',
#      'screen_name': 'MadeFurYou'}]},
#   'favorite_count': 0,
#   'favorited': False,
#   'geo': None,
#   'id': 838772152350420992,
#   'id_str': '838772152350420992',
#   'in_reply_to_screen_name': 'AshCoyote',
#   'in_reply_to_status_id': 837772060164255744,
#   'in_reply_to_status_id_str': '837772060164255744',
#   'in_reply_to_user_id': 545640747,
#   'in_reply_to_user_id_str': '545640747',
#   'is_quote_status': False,
#   'lang': 'en',
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'place': None,
#   'retweet_count': 0,
#   'retweeted': False,
#   'source': '<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>',
#   'text': '@AshCoyote @chipfoxx in the running for fluffiest too by the looks of him! @MadeFurYou',
#   'truncated': False,
#   'user': {'contributors_enabled': False,
#    'created_at': 'Thu Jul 03 07:48:59 +0000 2014',
#    'default_profile': False,
#    'default_profile_image': False,
#    'description': 'Back to gooey | electrician, locomotive technician, pro-union, hardware hacker, photographer, pervert, gamer. AD accounts go here: @kelfux',
#    'entities': {'description': {'urls': []}},
#    'favourites_count': 14215,
#    'follow_request_sent': None,
#    'followers_count': 349,
#    'following': None,
#    'friends_count': 360,
#    'geo_enabled': False,
#    'has_extended_profile': True,
#    'id': 2601222894,
#    'id_str': '2601222894',
#    'is_translation_enabled': True,
#    'is_translator': False,
#    'lang': 'en',
#    'listed_count': 13,
#    'location': 'Annville, PA',
#    'name': 'Bad Advice Donkey',
#    'notifications': None,
#    'profile_background_color': '000000',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/2601222894/1478770344',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/796644778385489920/C-zI7EUF_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/796644778385489920/C-zI7EUF_normal.jpg',
#    'profile_link_color': 'F58EA8',
#    'profile_sidebar_border_color': '000000',
#    'profile_sidebar_fill_color': '000000',
#    'profile_text_color': '000000',
#    'profile_use_background_image': False,
#    'protected': False,
#    'screen_name': 'ElkyAsno',
#    'statuses_count': 21500,
#    'time_zone': 'Eastern Time (US & Canada)',
#    'translator_type': 'none',
#    'url': None,
#    'utc_offset': -18000,
#    'verified': False}},
#  {'contributors': None,
#   'coordinates': None,
#   'created_at': 'Mon Mar 06 15:23:56 +0000 2017',
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'urls': [{'display_url': 'twitter.com/i/web/status/8…',
#      'expanded_url': 'https://twitter.com/i/web/status/838772140497383424',
#      'indices': [125, 148],
#      'url': 'https://t.co/7SfPTxWzwt'}],
#    'user_mentions': []},
#   'favorite_count': 0,
#   'favorited': False,
#   'geo': None,
#   'id': 838772140497383424,
#   'id_str': '838772140497383424',
#   'in_reply_to_screen_name': None,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'is_quote_status': False,
#   'lang': 'en',
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'place': None,
#   'possibly_sensitive': False,
#   'retweet_count': 0,
#   'retweeted': False,
#   'source': '<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>',
#   'text': 'Tue – Elders &amp; Deacons meeting, 6 PM\nWed – AWANA &amp; IGNITE, 6:30-8 PM\nThu – Men of Grace at 3Js, 6:30 AM\nSun – Grace… https://t.co/7SfPTxWzwt',
#   'truncated': True,
#   'user': {'contributors_enabled': False,
#    'created_at': 'Tue Nov 20 01:17:15 +0000 2012',
#    'default_profile': False,
#    'default_profile_image': False,
#    'description': 'Where Grace Meets Life!',
#    'entities': {'description': {'urls': []},
#     'url': {'urls': [{'display_url': 'gracelifepa.org',
#        'expanded_url': 'http://www.gracelifepa.org',
#        'indices': [0, 20],
#        'url': 'http://t.co/TI8sckWh'}]}},
#    'favourites_count': 1,
#    'follow_request_sent': None,
#    'followers_count': 47,
#    'following': None,
#    'friends_count': 2,
#    'geo_enabled': False,
#    'has_extended_profile': False,
#    'id': 959165431,
#    'id_str': '959165431',
#    'is_translation_enabled': False,
#    'is_translator': False,
#    'lang': 'en',
#    'listed_count': 1,
#    'location': 'Annville, PA',
#    'name': 'GraceLife Church',
#    'notifications': None,
#    'profile_background_color': '104D6B',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/959165431/1483374973',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/815960521119846400/sRxGv6x8_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/815960521119846400/sRxGv6x8_normal.jpg',
#    'profile_link_color': '0084B4',
#    'profile_sidebar_border_color': 'FFFFFF',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': False,
#    'protected': False,
#    'screen_name': 'gracelifepa',
#    'statuses_count': 233,
#    'time_zone': 'Eastern Time (US & Canada)',
#    'translator_type': 'none',
#    'url': 'http://t.co/TI8sckWh',
#    'utc_offset': -18000,
#    'verified': False}},
#  {'contributors': None,
#   'coordinates': None,
#   'created_at': 'Mon Mar 06 15:23:48 +0000 2017',
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'urls': [{'display_url': 'twitter.com/bso/status/838…',
#      'expanded_url': 'https://twitter.com/bso/status/838473787175759872',
#      'indices': [73, 96],
#      'url': 'https://t.co/c1NK1Fh73p'}],
#    'user_mentions': []},
#   'favorite_count': 0,
#   'favorited': False,
#   'geo': None,
#   'id': 838772108062834688,
#   'id_str': '838772108062834688',
#   'in_reply_to_screen_name': None,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'is_quote_status': True,
#   'lang': 'en',
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'place': None,
#   'possibly_sensitive': False,
#   'quoted_status': {'contributors': None,
#    'coordinates': None,
#    'created_at': 'Sun Mar 05 19:38:23 +0000 2017',
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'urls': [{'display_url': 'twitter.com/i/web/status/8…',
#       'expanded_url': 'https://twitter.com/i/web/status/838473787175759872',
#       'indices': [99, 122],
#       'url': 'https://t.co/GKWFTswaBO'}],
#     'user_mentions': []},
#    'favorite_count': 1244,
#    'favorited': False,
#    'geo': None,
#    'id': 838473787175759872,
#    'id_str': '838473787175759872',
#    'in_reply_to_screen_name': None,
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'is_quote_status': False,
#    'lang': 'en',
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'place': None,
#    'possibly_sensitive': False,
#    'retweet_count': 1562,
#    'retweeted': False,
#    'source': '<a href="http://BlackSportsOnline.com/home" rel="nofollow">BSO Alert</a>',
#    'text': 'Larsa Pippen on Forgiving &amp; Taking Back Scottie After She Cheated on Him With Future (Photos)… https://t.co/GKWFTswaBO',
#    'truncated': True,
#    'user': {'contributors_enabled': False,
#     'created_at': 'Sat Jan 10 02:06:55 +0000 2009',
#     'default_profile': False,
#     'default_profile_image': False,
#     'description': 'BlackSportsOnline & BSO ENT. Unique Perspective on Sports & Entertainment. Tweets by tOSU Alum & CEO @robertlittal IG: BlackSportsOnline Snapchat: RobertLittal',
#     'entities': {'description': {'urls': []},
#      'url': {'urls': [{'display_url': 'blacksportsonline.com',
#         'expanded_url': 'http://www.blacksportsonline.com',
#         'indices': [0, 23],
#         'url': 'https://t.co/yenl1qGfut'}]}},
#     'favourites_count': 61,
#     'follow_request_sent': None,
#     'followers_count': 87213,
#     'following': None,
#     'friends_count': 1344,
#     'geo_enabled': True,
#     'has_extended_profile': True,
#     'id': 18823758,
#     'id_str': '18823758',
#     'is_translation_enabled': False,
#     'is_translator': False,
#     'lang': 'en',
#     'listed_count': 1579,
#     'location': 'Los Angeles, CA',
#     'name': 'BlackSportsOnline',
#     'notifications': None,
#     'profile_background_color': '131516',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme14/bg.gif',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme14/bg.gif',
#     'profile_background_tile': True,
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/18823758/1449592279',
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/768471046164918273/S0Z0tqod_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/768471046164918273/S0Z0tqod_normal.jpg',
#     'profile_link_color': '950A0A',
#     'profile_sidebar_border_color': 'FFFFFF',
#     'profile_sidebar_fill_color': 'EFEFEF',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'protected': False,
#     'screen_name': 'BSO',
#     'statuses_count': 526382,
#     'time_zone': 'Central Time (US & Canada)',
#     'translator_type': 'none',
#     'url': 'https://t.co/yenl1qGfut',
#     'utc_offset': -21600,
#     'verified': True}},
#   'quoted_status_id': 838473787175759872,
#   'quoted_status_id_str': '838473787175759872',
#   'retweet_count': 1,
#   'retweeted': False,
#   'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#   'text': "It's cheaper to keep her at this point.... I'm sure Scottie got hoes too https://t.co/c1NK1Fh73p",
#   'truncated': False,
#   'user': {'contributors_enabled': False,
#    'created_at': 'Sun Jul 26 03:25:07 +0000 2009',
#    'default_profile': False,
#    'default_profile_image': False,
#    'description': "6'5....27....Snapchat: bwarelaflare...Pennsylvania...11/25....Eagles, 76ers, Penn State Football, Harrisburg Cougars",
#    'entities': {'description': {'urls': []},
#     'url': {'urls': [{'display_url': 'revcom.us/a/firstvol/cra…',
#        'expanded_url': 'http://www.revcom.us/a/firstvol/crack.htm',
#        'indices': [0, 23],
#        'url': 'https://t.co/da5QrvEdZH'}]}},
#    'favourites_count': 160085,
#    'follow_request_sent': None,
#    'followers_count': 5371,
#    'following': None,
#    'friends_count': 2070,
#    'geo_enabled': True,
#    'has_extended_profile': True,
#    'id': 60220819,
#    'id_str': '60220819',
#    'is_translation_enabled': False,
#    'is_translator': False,
#    'lang': 'en',
#    'listed_count': 121,
#    'location': 'Harrisburg, PA',
#    'name': 'Oroku Saki',
#    'notifications': None,
#    'profile_background_color': '9AE4E8',
#    'profile_background_image_url': 'http://pbs.twimg.com/profile_background_images/378800000096077137/c63976580ba99ed8239183e8dd4c6708.jpeg',
#    'profile_background_image_url_https': 'https://pbs.twimg.com/profile_background_images/378800000096077137/c63976580ba99ed8239183e8dd4c6708.jpeg',
#    'profile_background_tile': True,
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/60220819/1471216780',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/817051167960268800/le1YTYhi_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/817051167960268800/le1YTYhi_normal.jpg',
#    'profile_link_color': '4A913C',
#    'profile_sidebar_border_color': 'FFFFFF',
#    'profile_sidebar_fill_color': 'DDFFCC',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'protected': False,
#    'screen_name': 'BWare_LaFlare',
#    'statuses_count': 382523,
#    'time_zone': 'Eastern Time (US & Canada)',
#    'translator_type': 'none',
#    'url': 'https://t.co/da5QrvEdZH',
#    'utc_offset': -18000,
#    'verified': False}},
#  {'contributors': None,
#   'coordinates': None,
#   'created_at': 'Mon Mar 06 15:23:47 +0000 2017',
#   'entities': {'hashtags': [{'indices': [0, 13], 'text': 'keepitlocked'}],
#    'symbols': [],
#    'urls': [{'display_url': 'tunein.com/radio/WTBOY-10…',
#      'expanded_url': 'http://tunein.com/radio/WTBOY-1075-HBG-s208454/',
#      'indices': [74, 97],
#      'url': 'https://t.co/NSrgOrMyKh'}],
#    'user_mentions': []},
#   'favorite_count': 0,
#   'favorited': False,
#   'geo': None,
#   'id': 838772103671349248,
#   'id_str': '838772103671349248',
#   'in_reply_to_screen_name': None,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'is_quote_status': False,
#   'lang': 'en',
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'place': None,
#   'possibly_sensitive': False,
#   'retweet_count': 0,
#   'retweeted': False,
#   'source': '<a href="http://sam-song.info" rel="nofollow">SAM Broadcaster Song Info</a>',
#   'text': '#keepitlocked N/P: Lynn Tate feat. Rich Homie Quan - Down For You (Clean) https://t.co/NSrgOrMyKh',
#   'truncated': False,
#   'user': {'contributors_enabled': False,
#    'created_at': 'Mon Oct 08 12:50:26 +0000 2012',
#    'default_profile': False,
#    'default_profile_image': False,
#    'description': 'I Rock Clubs, Mixtapes Parties and also a Mix Show Dj on WTBOY 107.5  HBG INTERNET RADIO EVERYDAY, SEND ME A DROP AND YOUR TRACK!! \n(CLEAN) Stop the Violence!!',
#    'entities': {'description': {'urls': []},
#     'url': {'urls': [{'display_url': 'wtboy1075.com',
#        'expanded_url': 'http://www.wtboy1075.com',
#        'indices': [0, 22],
#        'url': 'http://t.co/ZCOSvmT7pg'}]}},
#    'favourites_count': 36,
#    'follow_request_sent': None,
#    'followers_count': 773,
#    'following': None,
#    'friends_count': 437,
#    'geo_enabled': False,
#    'has_extended_profile': False,
#    'id': 867943633,
#    'id_str': '867943633',
#    'is_translation_enabled': False,
#    'is_translator': False,
#    'lang': 'en',
#    'listed_count': 31,
#    'location': 'Harrisburg Pa.',
#    'name': 'WTBOY 107.5 HBG',
#    'notifications': None,
#    'profile_background_color': '000000',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/867943633/1421773367',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/711964123857158144/M2WOywgm_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/711964123857158144/M2WOywgm_normal.jpg',
#    'profile_link_color': '4A913C',
#    'profile_sidebar_border_color': '000000',
#    'profile_sidebar_fill_color': '000000',
#    'profile_text_color': '000000',
#    'profile_use_background_image': False,
#    'protected': False,
#    'screen_name': '1DJTBOYGOLD',
#    'statuses_count': 201125,
#    'time_zone': 'Eastern Time (US & Canada)',
#    'translator_type': 'none',
#    'url': 'http://t.co/ZCOSvmT7pg',
#    'utc_offset': -18000,
#    'verified': False}},
#  {'contributors': None,
#   'coordinates': None,
#   'created_at': 'Mon Mar 06 15:23:43 +0000 2017',
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'urls': [],
#    'user_mentions': [{'id': 3373881118,
#      'id_str': '3373881118',
#      'indices': [3, 15],
#      'name': 'Maya Sutton',
#      'screen_name': 'mayasutton_'}]},
#   'favorite_count': 0,
#   'favorited': False,
#   'geo': None,
#   'id': 838772085048606720,
#   'id_str': '838772085048606720',
#   'in_reply_to_screen_name': None,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'is_quote_status': False,
#   'lang': 'en',
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'place': None,
#   'retweet_count': 3,
#   'retweeted': False,
#   'retweeted_status': {'contributors': None,
#    'coordinates': None,
#    'created_at': 'Mon Mar 06 12:57:27 +0000 2017',
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'urls': [],
#     'user_mentions': []},
#    'favorite_count': 1,
#    'favorited': False,
#    'geo': None,
#    'id': 838735276906283008,
#    'id_str': '838735276906283008',
#    'in_reply_to_screen_name': None,
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'is_quote_status': False,
#    'lang': 'en',
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'place': None,
#    'retweet_count': 3,
#    'retweeted': False,
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'text': '"If we never speak again I\'m just glad I got to tell the truth"',
#    'truncated': False,
#    'user': {'contributors_enabled': False,
#     'created_at': 'Mon Jul 13 11:33:02 +0000 2015',
#     'default_profile': True,
#     'default_profile_image': False,
#     'description': '',
#     'entities': {'description': {'urls': []},
#      'url': {'urls': [{'display_url': 'instagram.com/maya.lyn',
#         'expanded_url': 'http://www.instagram.com/maya.lyn',
#         'indices': [0, 23],
#         'url': 'https://t.co/pZb01j6rgZ'}]}},
#     'favourites_count': 3426,
#     'follow_request_sent': None,
#     'followers_count': 339,
#     'following': None,
#     'friends_count': 435,
#     'geo_enabled': True,
#     'has_extended_profile': True,
#     'id': 3373881118,
#     'id_str': '3373881118',
#     'is_translation_enabled': False,
#     'is_translator': False,
#     'lang': 'en',
#     'listed_count': 11,
#     'location': 'York, PA',
#     'name': 'Maya Sutton',
#     'notifications': None,
#     'profile_background_color': 'C0DEED',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/3373881118/1485394309',
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/837085931299561474/f4x8v6S2_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/837085931299561474/f4x8v6S2_normal.jpg',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'protected': False,
#     'screen_name': 'mayasutton_',
#     'statuses_count': 4266,
#     'time_zone': None,
#     'translator_type': 'none',
#     'url': 'https://t.co/pZb01j6rgZ',
#     'utc_offset': None,
#     'verified': False}},
#   'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#   'text': 'RT @mayasutton_: "If we never speak again I\'m just glad I got to tell the truth"',
#   'truncated': False,
#   'user': {'contributors_enabled': False,
#    'created_at': 'Sat Jun 18 17:42:02 +0000 2011',
#    'default_profile': False,
#    'default_profile_image': False,
#    'description': "day one shordy @_nashyylk the most high Free Isiah Insha'Allah Rest Easy David Telp Jr Baltimore,MD ✈️PA Limitless",
#    'entities': {'description': {'urls': []}},
#    'favourites_count': 2643,
#    'follow_request_sent': None,
#    'followers_count': 931,
#    'following': None,
#    'friends_count': 686,
#    'geo_enabled': True,
#    'has_extended_profile': False,
#    'id': 319754864,
#    'id_str': '319754864',
#    'is_translation_enabled': False,
#    'is_translator': False,
#    'lang': 'en',
#    'listed_count': 3,
#    'location': '',
#    'name': 'DFG',
#    'notifications': None,
#    'profile_background_color': 'ACDED6',
#    'profile_background_image_url': 'http://pbs.twimg.com/profile_background_images/378800000104149780/271bbacc27ba6b03048def82c13a4091.jpeg',
#    'profile_background_image_url_https': 'https://pbs.twimg.com/profile_background_images/378800000104149780/271bbacc27ba6b03048def82c13a4091.jpeg',
#    'profile_background_tile': True,
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/319754864/1458694907',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/836665690895626240/VUAvfR9p_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/836665690895626240/VUAvfR9p_normal.jpg',
#    'profile_link_color': '038543',
#    'profile_sidebar_border_color': '000000',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'protected': False,
#    'screen_name': '_BmoreMartyr',
#    'statuses_count': 25413,
#    'time_zone': 'Pacific Time (US & Canada)',
#    'translator_type': 'regular',
#    'url': None,
#    'utc_offset': -28800,
#    'verified': False}},
#  {'contributors': None,
#   'coordinates': None,
#   'created_at': 'Mon Mar 06 15:23:41 +0000 2017',
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'urls': [{'display_url': 'twitter.com/conservative_v…',
#      'expanded_url': 'https://twitter.com/conservative_vw/status/838751454399639552',
#      'indices': [85, 108],
#      'url': 'https://t.co/TaUbAOCk0h'}],
#    'user_mentions': []},
#   'favorite_count': 0,
#   'favorited': False,
#   'geo': None,
#   'id': 838772077154947073,
#   'id_str': '838772077154947073',
#   'in_reply_to_screen_name': None,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'is_quote_status': True,
#   'lang': 'en',
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'place': None,
#   'possibly_sensitive': False,
#   'quoted_status': {'contributors': None,
#    'coordinates': None,
#    'created_at': 'Mon Mar 06 14:01:44 +0000 2017',
#    'entities': {'hashtags': [],
#     'media': [{'display_url': 'pic.twitter.com/ySGQKJHw5v',
#       'expanded_url': 'https://twitter.com/Conservative_VW/status/838751454399639552/photo/1',
#       'id': 838751447659356160,
#       'id_str': '838751447659356160',
#       'indices': [116, 139],
#       'media_url': 'http://pbs.twimg.com/media/C6PX_2yUoAA5JuW.jpg',
#       'media_url_https': 'https://pbs.twimg.com/media/C6PX_2yUoAA5JuW.jpg',
#       'sizes': {'large': {'h': 1073, 'resize': 'fit', 'w': 1143},
#        'medium': {'h': 1073, 'resize': 'fit', 'w': 1143},
#        'small': {'h': 638, 'resize': 'fit', 'w': 680},
#        'thumb': {'h': 150, 'resize': 'crop', 'w': 150}},
#       'type': 'photo',
#       'url': 'https://t.co/ySGQKJHw5v'}],
#     'symbols': [],
#     'urls': [],
#     'user_mentions': []},
#    'extended_entities': {'media': [{'display_url': 'pic.twitter.com/ySGQKJHw5v',
#       'expanded_url': 'https://twitter.com/Conservative_VW/status/838751454399639552/photo/1',
#       'id': 838751447659356160,
#       'id_str': '838751447659356160',
#       'indices': [116, 139],
#       'media_url': 'http://pbs.twimg.com/media/C6PX_2yUoAA5JuW.jpg',
#       'media_url_https': 'https://pbs.twimg.com/media/C6PX_2yUoAA5JuW.jpg',
#       'sizes': {'large': {'h': 1073, 'resize': 'fit', 'w': 1143},
#        'medium': {'h': 1073, 'resize': 'fit', 'w': 1143},
#        'small': {'h': 638, 'resize': 'fit', 'w': 680},
#        'thumb': {'h': 150, 'resize': 'crop', 'w': 150}},
#       'type': 'photo',
#       'url': 'https://t.co/ySGQKJHw5v'}]},
#    'favorite_count': 82,
#    'favorited': False,
#    'geo': None,
#    'id': 838751454399639552,
#    'id_str': '838751454399639552',
#    'in_reply_to_screen_name': None,
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'is_quote_status': False,
#    'lang': 'en',
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'place': None,
#    'possibly_sensitive': False,
#    'retweet_count': 32,
#    'retweeted': False,
# ...
#    'possibly_sensitive': False,
#    'retweet_count': 115,
#    'retweeted': False,
#    'source': '<a href="https://www.sprinklr.com" rel="nofollow">Sprinklr</a>',
#    'text': '"Feminism is about giving women choice": Emma Watson responds to critics of a photo that appeared in Vanity Fair… https://t.co/7YXmKWonHu',
#    'truncated': True,
#    'user': {'contributors_enabled': False,
#     'created_at': 'Fri Feb 09 00:35:02 +0000 2007',
#     'default_profile': False,
#     'default_profile_image': False,
#     'description': 'It’s our job to #GoThere and tell the most difficult stories. Come with us!\n\n➡︎ For more breaking news updates follow @CNNBRK',
#     'entities': {'description': {'urls': []},
#      'url': {'urls': [{'display_url': 'cnn.com',
#         'expanded_url': 'http://www.cnn.com',
#         'indices': [0, 22],
#         'url': 'http://t.co/IaghNW8Xm2'}]}},
#     'favourites_count': 1461,
#     'follow_request_sent': None,
#     'followers_count': 32299936,
#     'following': None,
#     'friends_count': 1118,
#     'geo_enabled': True,
#     'has_extended_profile': False,
#     'id': 759251,
#     'id_str': '759251',
#     'is_translation_enabled': True,
#     'is_translator': False,
#     'lang': 'en',
#     'listed_count': 124611,
#     'location': '',
#     'name': 'CNN',
#     'notifications': None,
#     'profile_background_color': '323232',
#     'profile_background_image_url': 'http://pbs.twimg.com/profile_background_images/515228058286952449/zVfUxqPl.jpeg',
#     'profile_background_image_url_https': 'https://pbs.twimg.com/profile_background_images/515228058286952449/zVfUxqPl.jpeg',
#     'profile_background_tile': False,
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/759251/1486579954',
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/508960761826131968/LnvhR8ED_normal.png',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/508960761826131968/LnvhR8ED_normal.png',
#     'profile_link_color': '004287',
#     'profile_sidebar_border_color': '000000',
#     'profile_sidebar_fill_color': 'EEEEEE',
#     'profile_text_color': '000000',
#     'profile_use_background_image': False,
#     'protected': False,
#     'screen_name': 'CNN',
#     'statuses_count': 120701,
#     'time_zone': 'Eastern Time (US & Canada)',
#     'translator_type': 'regular',
#     'url': 'http://t.co/IaghNW8Xm2',
#     'utc_offset': -18000,
#     'verified': True}},
#   'quoted_status_id': 838771307458199552,
#   'quoted_status_id_str': '838771307458199552',
#   'retweet_count': 0,
#   'retweeted': False,
#   'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#   'text': '"Feminism is not a stick with which to hit other women" ❤️👏🏻💪🏻 https://t.co/i09DLDHzoN',
#   'truncated': False,
#   'user': {'contributors_enabled': False,
#    'created_at': 'Wed Mar 23 19:49:20 +0000 2011',
#    'default_profile': False,
#    'default_profile_image': False,
#    'description': 'PR at ShellyLyons, but tweets are mine. Two-time @LehighU grad (BA & MA). Semi-pro cellist. #Feminist, but answers to Mrs. @SeanCrampsie',
#    'entities': {'description': {'urls': []},
#     'url': {'urls': [{'display_url': 'brittanyleighfoster.wordpress.com',
#        'expanded_url': 'http://brittanyleighfoster.wordpress.com/',
#        'indices': [0, 23],
#        'url': 'https://t.co/H92manwu43'}]}},
#    'favourites_count': 6175,
#    'follow_request_sent': None,
#    'followers_count': 2072,
#    'following': None,
#    'friends_count': 2750,
#    'geo_enabled': True,
#    'has_extended_profile': True,
#    'id': 271062543,
#    'id_str': '271062543',
#    'is_translation_enabled': False,
#    'is_translator': False,
#    'lang': 'en',
#    'listed_count': 80,
#    'location': 'Carlisle, PA',
#    'name': 'Brittany Crampsie',
#    'notifications': None,
#    'profile_background_color': '000000',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme17/bg.gif',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme17/bg.gif',
#    'profile_background_tile': False,
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/271062543/1487014068',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/832695808273240065/A5yKKhsC_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/832695808273240065/A5yKKhsC_normal.jpg',
#    'profile_link_color': 'ABB8C2',
#    'profile_sidebar_border_color': '000000',
#    'profile_sidebar_fill_color': '000000',
#    'profile_text_color': '000000',
#    'profile_use_background_image': False,
#    'protected': False,
#    'screen_name': 'BritCrampsie',
#    'statuses_count': 24181,
#    'time_zone': 'Quito',
#    'translator_type': 'none',
#    'url': 'https://t.co/H92manwu43',
#    'utc_offset': -18000,
#    'verified': False}},
#  {'contributors': None,
#   'coordinates': None,
#   'created_at': 'Mon Mar 06 15:23:16 +0000 2017',
#   'entities': {'hashtags': [], 'symbols': [], 'urls': [], 'user_mentions': []},
#   'favorite_count': 0,
#   'favorited': False,
#   'geo': None,
#   'id': 838771973035544577,
#   'id_str': '838771973035544577',
#   'in_reply_to_screen_name': None,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'is_quote_status': False,
#   'lang': 'en',
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'place': None,
#   'retweet_count': 0,
#   'retweeted': False,
#   'source': '<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>',
#   'text': '1 Peter 1:21 Through him you believe in  God, who raised him from the dead and glorified him, and so your faith  and hope are in God.',
#   'truncated': False,
#   'user': {'contributors_enabled': False,
#    'created_at': 'Sat Feb 25 23:48:48 +0000 2017',
#    'default_profile': True,
#    'default_profile_image': False,
#    'description': '',
#    'entities': {'description': {'urls': []},
#     'url': {'urls': [{'display_url': 'salemumchmanheim.org',
#        'expanded_url': 'http://salemumchmanheim.org',
#        'indices': [0, 23],
#        'url': 'https://t.co/Im7yqsAJXh'}]}},
#    'favourites_count': 0,
#    'follow_request_sent': None,
#    'followers_count': 0,
#    'following': None,
#    'friends_count': 0,
#    'geo_enabled': False,
#    'has_extended_profile': False,
#    'id': 835637700497637376,
#    'id_str': '835637700497637376',
#    'is_translation_enabled': False,
#    'is_translator': False,
#    'lang': 'en',
#    'listed_count': 0,
#    'location': 'Manheim, PA',
#    'name': 'Salem UMC Manheim',
#    'notifications': None,
#    'profile_background_color': 'F5F8FA',
#    'profile_background_image_url': None,
#    'profile_background_image_url_https': None,
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/835638376841764864/oURu6vdo_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/835638376841764864/oURu6vdo_normal.jpg',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'protected': False,
#    'screen_name': 'salemumcmanheim',
#    'statuses_count': 5,
#    'time_zone': None,
#    'translator_type': 'none',
#    'url': 'https://t.co/Im7yqsAJXh',
#    'utc_offset': None,
#    'verified': False}},
#  {'contributors': None,
#   'coordinates': None,
#   'created_at': 'Mon Mar 06 15:23:15 +0000 2017',
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'urls': [{'display_url': 'fb.me/1tMYzChTo',
#      'expanded_url': 'http://fb.me/1tMYzChTo',
#      'indices': [117, 140],
#      'url': 'https://t.co/iXrEQh7Asb'}],
#    'user_mentions': []},
#   'favorite_count': 0,
#   'favorited': False,
#   'geo': None,
#   'id': 838771967343869953,
#   'id_str': '838771967343869953',
#   'in_reply_to_screen_name': None,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'is_quote_status': False,
#   'lang': 'en',
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'place': None,
#   'possibly_sensitive': False,
#   'retweet_count': 0,
#   'retweeted': False,
#   'source': '<a href="http://www.facebook.com/twitter" rel="nofollow">Facebook</a>',
#   'text': "SHANE'S TOP 10 HOMEMADE MUSIC IDEAS + gigs and guitars from the vault.  Check it out... the newsletter looks cool... https://t.co/iXrEQh7Asb",
#   'truncated': False,
#   'user': {'contributors_enabled': False,
#    'created_at': 'Mon Jul 21 19:06:15 +0000 2008',
#    'default_profile': True,
#    'default_profile_image': False,
#    'description': "OFFICIAL SHANE SPEAL - The King of the Cigar Box Guitar.  Performer, musician, historian, lover of good beers.  Cigar box guitar museum at Speal's Tavern.",
#    'entities': {'description': {'urls': []},
#     'url': {'urls': [{'display_url': 'shanespeal.com',
#        'expanded_url': 'http://shanespeal.com',
#        'indices': [0, 22],
#        'url': 'http://t.co/eKYZQxiPAS'}]}},
#    'favourites_count': 22,
#    'follow_request_sent': None,
#    'followers_count': 858,
#    'following': None,
#    'friends_count': 386,
#    'geo_enabled': False,
#    'has_extended_profile': False,
#    'id': 15519164,
#    'id_str': '15519164',
#    'is_translation_enabled': False,
#    'is_translator': False,
#    'lang': 'en',
#    'listed_count': 17,
#    'location': 'York, PA',
#    'name': 'cigarboxguitar',
#    'notifications': None,
#    'profile_background_color': 'C0DEED',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/2573821684/ip7jztqkt8zh2ns8h33z_normal.jpeg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/2573821684/ip7jztqkt8zh2ns8h33z_normal.jpeg',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'protected': False,
#    'screen_name': 'cigarboxguitar',
#    'statuses_count': 6857,
#    'time_zone': 'Quito',
#    'translator_type': 'none',
#    'url': 'http://t.co/eKYZQxiPAS',
#    'utc_offset': -18000,
#    'verified': False}},
#  {'contributors': None,
#   'coordinates': None,
#   'created_at': 'Mon Mar 06 15:23:15 +0000 2017',
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'urls': [],
#    'user_mentions': [{'id': 193404963,
#      'id_str': '193404963',
#      'indices': [3, 19],
#      'name': 'Wildcat Athletics',
#      'screen_name': 'GoMechanicsburg'}]},
#   'favorite_count': 0,
#   'favorited': False,
#   'geo': None,
#   'id': 838771966555324416,
#   'id_str': '838771966555324416',
#   'in_reply_to_screen_name': None,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'is_quote_status': False,
#   'lang': 'en',
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'place': None,
#   'retweet_count': 11,
#   'retweeted': False,
#   'retweeted_status': {'contributors': None,
#    'coordinates': None,
#    'created_at': 'Sun Mar 05 17:38:32 +0000 2017',
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'urls': [],
#     'user_mentions': []},
#    'favorite_count': 17,
#    'favorited': False,
#    'geo': None,
#    'id': 838443625910530049,
#    'id_str': '838443625910530049',
#    'in_reply_to_screen_name': None,
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'is_quote_status': False,
#    'lang': 'en',
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'place': None,
#    'retweet_count': 11,
#    'retweeted': False,
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'text': 'Boys Basketball will play Springfield Delco on Friday at 8:00PM at Hershey High School in the first rd of the state tournament.',
#    'truncated': False,
#    'user': {'contributors_enabled': False,
#     'created_at': 'Tue Sep 21 18:52:29 +0000 2010',
#     'default_profile': False,
#     'default_profile_image': False,
#     'description': 'The official twitter account of the Mechanicsburg Area School District Athletic Department. Tradition, Pride, Excellence. WILDCAT PRIDE!',
#     'entities': {'description': {'urls': []},
#      'url': {'urls': [{'display_url': 'gomechanicsburg.com',
#         'expanded_url': 'http://www.gomechanicsburg.com',
#         'indices': [0, 22],
#         'url': 'http://t.co/Jnomj0zMgu'}]}},
#     'favourites_count': 20,
#     'follow_request_sent': None,
#     'followers_count': 2088,
#     'following': None,
#     'friends_count': 115,
#     'geo_enabled': True,
#     'has_extended_profile': False,
#     'id': 193404963,
#     'id_str': '193404963',
#     'is_translation_enabled': False,
#     'is_translator': False,
#     'lang': 'en',
#     'listed_count': 22,
#     'location': 'Mechanicsburg, PA USA',
#     'name': 'Wildcat Athletics',
#     'notifications': None,
#     'profile_background_color': 'C0DEED',
#     'profile_background_image_url': 'http://pbs.twimg.com/profile_background_images/372818815/Twitter-Background-MechAthletics.jpg',
#     'profile_background_image_url_https': 'https://pbs.twimg.com/profile_background_images/372818815/Twitter-Background-MechAthletics.jpg',
#     'profile_background_tile': False,
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/193404963/1439181117',
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1701074214/Wildcat_Light_Gray_normal.png',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1701074214/Wildcat_Light_Gray_normal.png',
#     'profile_link_color': '0084B4',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'protected': False,
#     'screen_name': 'GoMechanicsburg',
#     'statuses_count': 14813,
#     'time_zone': 'Eastern Time (US & Canada)',
#     'translator_type': 'none',
#     'url': 'http://t.co/Jnomj0zMgu',
#     'utc_offset': -18000,
#     'verified': False}},
#   'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#   'text': 'RT @GoMechanicsburg: Boys Basketball will play Springfield Delco on Friday at 8:00PM at Hershey High School in the first rd of the state to…',
#   'truncated': False,
#   'user': {'contributors_enabled': False,
#    'created_at': 'Tue Jul 02 17:36:37 +0000 2013',
#    'default_profile': True,
#    'default_profile_image': False,
#    'description': '| burg 17 || Romans 8:28 |',
#    'entities': {'description': {'urls': []}},
#    'favourites_count': 858,
#    'follow_request_sent': None,
#    'followers_count': 340,
#    'following': None,
#    'friends_count': 334,
#    'geo_enabled': False,
#    'has_extended_profile': True,
#    'id': 1563737323,
#    'id_str': '1563737323',
#    'is_translation_enabled': False,
#    'is_translator': False,
#    'lang': 'en',
#    'listed_count': 1,
#    'location': '',
#    'name': 'Adam Laudenslager',
#    'notifications': None,
#    'profile_background_color': 'C0DEED',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1563737323/1487731796',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/770447166347378688/yzO21YOC_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/770447166347378688/yzO21YOC_normal.jpg',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'protected': False,
#    'screen_name': 'alaudy99',
#    'statuses_count': 501,
#    'time_zone': None,
#    'translator_type': 'none',
#    'url': None,
#    'utc_offset': None,
#    'verified': False}}]

# %% [markdown]
# ### 4. Automate it - Hit the API and Parse the Result
#
# We are going to create a function to help us repeatedly hit the API, and parse the result into a readable JSON that contains the things that we are interested in, and still stores the raw tweet as an additional property. The returned object is a Python `dict` that we can easily parse into another dictionary to later store as a JSON. Raw JSONs returned from the API have a specific structure.
#
# It can be sometimes hard to read a raw JSON. I find it easy to use some online parsers like [this]( http://jsonparseronline.com/) to look at the structure of the JSON, and only access what we care about.
#
# Note: Remember we are limited to 450 every 15 minutes.

# %%
# Does pretty much what its long name suggests.
def get_lots_of_tweets( latlong ):
    # Create a dictionary to parse the JSON
    all_tweets = {}
    
    # We will be hitting the API a number of times within the total time
    total_time = 10
    
    # Everytime we hit the API we subtract time from the total
    remaining_seconds = total_time
    interval = 5
    while remaining_seconds > 0: # loop and run the function while remaining seconds is greater than zero
        added = 0
        # Hit the Twitter API using our function
        new_tweets = get_tweets_by_location(latlong) # we set latlong above!
        # Parse the resulting JSON, and save the rest of the raw content
        for tweet in new_tweets:
            tid = tweet['id']
            if tid not in all_tweets:
                properties = {}
                if tweet['coordinates'] != None:
                    properties['lat'] = tweet['coordinates']['coordinates'][0]
                    properties['lon'] = tweet['coordinates']['coordinates'][1]
                else:
                    properties['lat'] = None
                    properties['lon'] = None
                properties['location'] = tweet['user']['location'] #This will get us the location associated with the profile
                properties['tweet_id'] = tid
                properties['content'] = tweet['text']
                properties['user'] = tweet['user']['id']
                properties['raw_source'] = tweet
                properties['data_point'] = 'none'
                properties['time'] = tweet['created_at']
                all_tweets[ tid ] = properties
                added += 1
        print("At %d seconds, added %d new tweets, for a total of %d" % ( total_time - remaining_seconds, added, len( all_tweets )))
        # We wait a few seconds and hit the API again
        time.sleep(interval)
        remaining_seconds -= interval
    print(str(len(all_tweets)) + ' Tweets retrieved.')
    # We return the final dictionary to work with in Python
    return all_tweets

# %% [markdown]
# ### 5. Run the Twitter Scraper
#
# We need to call the functions, and save the JSONs into a location. In this case, I made a folder called **data**, where I am saving all the new JSONS. We can run the code continuously utilizing some loop, or we can use libraries like [threading](https://docs.python.org/3.6/library/threading.html).
#
# *Make sure you have a folder named **data** in the directory with your notebook! This function will save our collected datafiles to it when it finishes running.*

# %%
# This function executes the the functions over a given period of time
def run_all():
    # This is the number of times the code will be executed. In this case, just once. 
    starting = 1
    while starting > 0:
        # Sometimes the API returns some errors, killing the whole script, so we setup try/except to make sure it keeps running
        try:
            t = get_lots_of_tweets( latlong )
            # We name every file with the current time
            timestr = time.strftime("%Y%m%d-%H%M%S")
            # We write a new JSON into the target path
            with open( 'data/' + '%stweets.json' %(timestr), 'w' ) as f:
                f.write(json.dumps(t))
            # we can use a library like threading to execute the run function continuously.
            #threading.Timer(10, run).start()
            starting -= 1
        except:
            pass
    
run_all()

# %% [markdown]
# ### 6. Let's Explore the Data we Saved to our Machine
#
# Let's look through the JSON we created and checkout some of the data we just downloaded. First, let's import a couple of additional libraries that will let us interact with our file system, use numpy and pandas, and create plots:

# %%
# Import some additional libraries that will allow us to plot and interact with the operating system
from os import listdir
from os.path import isfile, join
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# Next, let's explore our data a bit. This following function will allow us to perform a visual examination of what we downloaded from Twitter. Once we have collected some data, we can parse it, and visualize some of the results. Since some of the data is repeated, we can initialize some lists to check whether or not a tweet already exists, and add it to the list. We can then extract the useful information for our purposes, and store it in another list.
#
# Building on last week, we can do this in Pandas.

# %%
# Get the file names from a given directory
file_dir = "data" # Set this to where your JSON saved
# Get only the JSONs we have saved
onlyfiles = [ f for f in listdir(file_dir) if isfile(join(file_dir,f)) and not f.startswith('.')]

# create an empty dataframe with columns for each property
df_tweets = pd.DataFrame(columns = ['tweet_id', 'lat', 'lon', 'content','location','user','raw_source','data_point','time'])

# Loop through all the files
for file in onlyfiles:
    full_dir = join(file_dir,file) 
    with open(full_dir) as json_data:
        dict = json.load(json_data) # creates a Python dictionary of our json
        if not isinstance(dict, list):
            for key, val in dict.items():
                df_tweets.loc[key,val] = val
                
df_tweets

# %% [markdown]
# ### 7. Summarize, Group, and Plot the Dataset
#
# Next let's summarize and group our data, and create some plots.
#
# **A** - First, group by the user location. This is not lat/lon, but rather the information the individual has input on their profile.
#
# When you give people the power to input their own location, you get an assortment of 'creative' responses!

# %%
df_tweets.dtypes

# %%
df_tweets['location'].unique()

# %% [markdown]
# Now let's do some grouping and sorting. We are using Pandas to do our analysis, much like last week.

# %%
grouped_tweets = df_tweets.groupby('location')
count_tweets = grouped_tweets['location'].count()
df_count_tweets = count_tweets.to_frame()
df_count_tweets.columns = ['Count']
df_count_tweets.index.names = ['Location']
df_count_tweets.sort_index()

# %% [markdown]
# Let's create a pie chart of these using matplotlib.

# %%
# Create a list of colors (from iWantHue)
colors = ["#697dc6","#5faf4c","#7969de","#b5b246",
          "#cc54bc","#4bad89","#d84577","#4eacd7",
          "#cf4e33","#894ea8","#cf8c42","#d58cc9",
          "#737632","#9f4b75","#c36960"]

# Create a pie chart
plt.pie( df_count_tweets['Count'], labels=df_count_tweets.index.get_values(), shadow=False, colors=colors)

# View the plot drop above
plt.axis('equal')

# View the plot
plt.tight_layout()
plt.show()

# %% [markdown]
# There are quite a few duplicates that we can clearly see, you will likely want to clean this data to rectify this.

# %% [markdown]
# **B** - Next, let's find how many actually have a location and put them on a scatterplot. To do this, we need to find first the rows where lat and long are not None, and then create the plot from just that subset of the data. Let's give it a go.

# %%
# Create a filter from df_tweets filtering only those that have values for lat and lon
df_tweets_with_location = df_tweets[df_tweets.lon.notnull() & df_tweets.lat.notnull()]
df_tweets_with_location

# %%
# Use a scatter plot to make a quick visualization of the data points
# NOTE: WHEN I DID THIS, I ONLY HAD SIX OUT OF ABOUT 100 TWEETS!
plt.scatter(df_tweets_with_location['lon'],df_tweets_with_location['lat'], s=25)
plt.show()

# %% [markdown]
# ### 8. Clean the Data
#
# **Clean the Locations** - You saw above that we had a bunch of locations that were very similar. Here, we could use [replace](http://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.replace.html). For example, we could replace all the variations of **York, PA** with a singular string using something like the following:

# %%
# List of variations of York
variations_of_york = ['York, PA','York PA','York, Pennsylvania','York, Pa','41 W Market Street York, Pa','york P.a. ','York, Pa.']

df_tweets['location'].replace(variations_of_york, 'York, PA')

# %% [markdown]
# **Remove Duplicates** - Make sure that we don't get tweets plotted more than once. How would you make sure to only plot unique tweets? We can maybe use [drop_duplicates](http://chrisalbon.com/python/pandas_delete_duplicates.html)

# %% [markdown]
# ### 9. Exporting your Data to CSV
#
# Exporting your dataset is easy, you can use **to_csv()**. This [Stack Exchange](http://stackoverflow.com/questions/16923281/pandas-writing-dataframe-to-csv-file) page will help you.

# %%
df_tweets.to_csv('twitter_data.csv', sep=',', encoding='utf-8')

# %% [markdown]
# ### Problem Set 3 - Extend What You Have Learned
#
# Now that you know how to scrape data from Twitter, let's extend the exercise a little so you can show us what you know. This time you will set up the scraper to get data around MIT and scrape data for 20 minutes. Then you will visualize it with  and visualize. Think about what you would need to change to do that.
#
# Once you have the new JSON file of Boston tweets you should a pie chart and scatterplot of your collected tweets. When you are creating your dataset, you should get at least two different attributes returned by the Twitter API (we got many of them above, so base it off of that example). Atleast one of them should be the tweet id. Make sure you remove and duplicate tweets (if any). Expanding on the above, then save the data to a CSV.
#
# Make sure you get your own Twitter Key.
#
# #### Deliverables
#
# **1** - Using the Twitter REST API, collect Tweets from Boston for 30 min. Note how you set the time in the above example (in the **run_all()** function), it was in seconds. How would you do that here?
#
# **2** - Create a Pie Chart showing a summary of tweets by user location. Please clean up the data so that multiple variations of the same location name are replaced with one variation.
#
# **3** - Create a Scatterplot showing all of the tweets that had a latitude and longitude.
#
# **4** - Pick a search term, such as *Trump* or *#Trump* and collect 15 minutes of tweets on it. Use the same lat/lon for Boston as you used above.
#
# **5** - Export the entirety of your scraped Twitter datasets (one with a search term, one without) to two CSV files. We will be checking this CSV file for duplicates. So clean your file.
#
# ### What to Give Us on Stellar
#
# 1 - Create a new Jupyter notebook that contains your scraper code. You can copy much of this one, but customize it. Submit the new Jupyter notebook, which includes your pie chart and scatterplot.
#
# 2 - Your final CSV files.
